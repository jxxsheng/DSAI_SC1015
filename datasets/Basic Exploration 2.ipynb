# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
ds_salaries = pd.read_csv("salary_final.csv")

# %%
ds_salaries.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                               Title  \
# 0             0           2  2021048 Data Scientist $215,000.00
# 1             1           2  2021048 Data Scientist $215,000.00
# 2             2           6           Data Science/Data Analyst
# 3             3           6           Data Science/Data Analyst
# 4             4           8                 Data Science Intern
#
#           Company                                               Link  Review  \
# 0          B4CORP  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     NaN
# 1          B4CORP  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     NaN
# 2       CRAiC LLC  https://www.indeed.com/company/CRAiC-LLC/jobs/...     NaN
# 3       CRAiC LLC  https://www.indeed.com/company/CRAiC-LLC/jobs/...     NaN
# 4  MilliporeSigma  https://www.indeed.com/company/Serono/jobs/Dat...     3.9
#
#                   Salary                                        Description  \
# ...

# %%
ds_salaries.shape
# Out:
# (1008, 25)

# %%
ds_salaries.isna().sum()
# Out:
# Unnamed: 0.1                        0
# Unnamed: 0                          0
# Title                               0
# Company                             0
# Link                                0
# Review                            501
# Salary                              0
# Description                         0
# Location2                           5
# Rate_by                             0
# low                                 0
# high                              210
# min                                 0
# max                                 0
# adjusted_salary                     0
# adjusted_yearly_salary              0
# Rank                               70
# City                               70
# Cost of Living Index               70
# Rent Index                         70
# Cost of Living Plus Rent Index     70
# Groceries Index                    70
# Restaurant Price Index             70
# Local Purchasing Power Index       70
# combined_text                       0
# ...

# %%
ds_salaries.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0      Review            min            max  \
# count   1008.000000  1008.000000  507.000000    1008.000000    1008.000000
# mean     503.500000  3200.226190    3.987968   62212.368333   64738.237014
# std      291.128837  2083.758355    0.656853   57733.284531   73344.527810
# min        0.000000     2.000000    2.300000       7.250000       0.000000
# 25%      251.750000  1403.500000    3.500000      55.000000      25.000000
# 50%      503.500000  3076.000000    4.000000   60000.000000   55600.000000
# 75%      755.250000  5073.500000    4.550000   97520.000000  116500.000000
# max     1007.000000  7261.000000    5.000000  300000.000000  500000.000000
#
#        adjusted_salary  adjusted_yearly_salary        Rank  \
# count      1008.000000             1008.000000  938.000000
# mean      71250.797604            99688.213591   21.262260
# std       64968.998187            50030.066246   18.219739
# ...

# %%
ds_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0.1                    1008 non-null   int64
#  1   Unnamed: 0                      1008 non-null   int64
#  2   Title                           1008 non-null   object
#  3   Company                         1008 non-null   object
#  4   Link                            1008 non-null   object
#  5   Review                          507 non-null    float64
#  6   Salary                          1008 non-null   object
#  7   Description                     1008 non-null   object
#  8   Location2                       1003 non-null   object
#  9   Rate_by                         1008 non-null   object
#  10  low                             1008 non-null   object
#  11  high                            798 non-null    object
# ...

# %%
ds_salaries.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0                            Title  \
# 1003          1003        7192              Data Engineering II
# 1004          1004        7199                     IR Day Shift
# 1005          1005        7208                Security Engineer
# 1006          1006        7212                      FDP Analyst
# 1007          1007        7261  Junior MS Access/ VBA Developer
#
#                        Company  \
# 1003   Pueo Business Solutions
# 1004   Pueo Business Solutions
# 1005   Pueo Business Solutions
# 1006         GC Associates USA
# 1007  Empirical Concepts, Inc.
#
#                                                    Link  Review  \
# 1003  https://www.indeed.com/rc/clk?jk=90a6c966f45f8...     5.0
# 1004  https://www.indeed.com/rc/clk?jk=e4416ec0bed30...     5.0
# 1005  https://www.indeed.com/rc/clk?jk=c06c7f39a6074...     5.0
# 1006  https://www.indeed.com/rc/clk?jk=84a4b28b5c409...     NaN
# ...

# %%
ds_salaries.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Title', 'Company', 'Link', 'Review',
#        'Salary', 'Description', 'Location2', 'Rate_by', 'low', 'high', 'min',
#        'max', 'adjusted_salary', 'adjusted_yearly_salary', 'Rank', 'City',
#        'Cost of Living Index', 'Rent Index', 'Cost of Living Plus Rent Index',
#        'Groceries Index', 'Restaurant Price Index',
#        'Local Purchasing Power Index', 'combined_text'],
#       dtype='object')

# %%
# Checking value counts for each column in the dataset
value_counts = {column: ds_salaries[column].value_counts() for column in ds_salaries.columns}

value_counts
# Out:
# {'Unnamed: 0.1': Unnamed: 0.1
#  0       1
#  677     1
#  664     1
#  665     1
#  666     1
#         ..
#  340     1
#  341     1
#  342     1
#  343     1
#  1007    1
#  Name: count, Length: 1008, dtype: int64,
#  'Unnamed: 0': Unnamed: 0
#  2       2
#  175     2
#  104     2
#  109     2
#  129     2
#         ..
#  2562    1
#  2572    1
#  2574    1
#  2575    1
#  7261    1
#  Name: count, Length: 963, dtype: int64,
#  'Title': Title
#  Data Scientist                                      37
#  Data Engineer                                       23
#  Business Analyst                                    15
#  Senior Software Engineer                            13
#  Data Analyst                                        12
#                                                      ..
#  Digital Marketing Analyst (Content and Graphics)     1
#  Database Analyst                                     1
#  Quality Audit Administrator                          1
# ...
